# %% [markdown]
# <a href="https://colab.research.google.com/github/Akbar-AI97/ai_foundation/blob/main/pandas_MIT36.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# --------- SHOURTCUTS ------------
# 1. shift + enter => open a new cell
# 2. cmd + enter => run current cell
# 3. shift + cmd + enter => run a specific line
# 4. cmd + / => comment the current line
# 5. shift + # => comment after the code in the current line
# 6. cmd + M + D => delete current cell

# %%
# pip install pandas

# %%
import pandas as pd

# %%
# pandas version check
print(pd.__version__)
# Out:
# 2.2.2

# %%
# DataFrame() - forms a tabular data

mydataset = {
    'cars': ["BMW", "Volvo", "Ford", "Tesla", "Ferrari", "Ford", "BMW"],
    'counts': [3, 7, 2, 8, 1, 9, 3]
}

df = pd.DataFrame(mydataset)
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5     Ford       9
# 6      BMW       3

# %% [markdown]
#  ------------- METHODS --------------

# %%
# head() - first 5 rows by default
df.head()
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1

# %%
# tail() - last 5 rows by default
df.tail()
# Out:
#       cars  counts
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5     Ford       9
# 6      BMW       3

# %%
# shape

df.shape
# Out:
# (7, 2)

# %%
# columns

df.columns
# Out:
# Index(['cars', 'counts'], dtype='object')

# %%
# dtypes

df.dtypes
# Out:
# cars      object
# counts     int64
# dtype: object

# %%
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5     Ford       9
# 6      BMW       3

# %%
# describe() - numerical columns only

df.describe()

# count -> Number of non-missing (non-NaN) values
# mean  -> Average value of the column
# std   -> Standard deviation (how spread out the values are)
# min   -> Smallest value in the column
# 25%   -> First quartile (25% of values are below this)
# 50%   -> Median (middle value, 50th percentile)
# 75%   -> Third quartile (75% of values are below this)
# max   -> Largest value in the column
# Out:
#          counts
# count  7.000000
# mean   4.714286
# std    3.199702
# min    1.000000
# 25%    2.500000
# 50%    3.000000
# 75%    7.500000
# max    9.000000

# %%
df.describe(include="all")
# Out:
#        cars    counts
# count     7  7.000000
# unique    5       NaN
# top     BMW       NaN
# freq      2       NaN
# mean    NaN  4.714286
# std     NaN  3.199702
# min     NaN  1.000000
# 25%     NaN  2.500000
# 50%     NaN  3.000000
# 75%     NaN  7.500000
# max     NaN  9.000000

# %%
# iloc - selects a specific row

df.iloc[0]
# Out:
# cars      BMW
# counts      3
# Name: 0, dtype: object

# %%
df.iloc[1:4] # [1, 4)
# Out:
#     cars  counts
# 1  Volvo       7
# 2   Ford       2
# 3  Tesla       8

# %%
df.iloc[2:] # [2, end]
# Out:
#       cars  counts
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5     Ford       9
# 6      BMW       3

# %%
# loc[row, "column_name"]

df.loc[2:5, "cars"]
# Out:
# 2       Ford
# 3      Tesla
# 4    Ferrari
# 5       Ford
# Name: cars, dtype: object

# %%
# Conditional Selection / Filtering

df["counts"] > 3
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# Name: counts, dtype: bool

# %%
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5     Ford       9
# 6      BMW       3

# %%
df[df["counts"] <= 3]
# Out:
#       cars  counts
# 0      BMW       3
# 2     Ford       2
# 4  Ferrari       1
# 6      BMW       3

# %%
df[df["cars"] == "BMW"]
# Out:
#   cars  counts
# 0  BMW       3
# 6  BMW       3

# %%
# df.mean(numeric_only=True)
df["counts"].mean()
# Out:
# np.float64(4.714285714285714)

# %%
df.sum()
# Out:
# cars      BMWVolvoFordTeslaFerrariFordBMW
# counts                                 33
# dtype: object

# %%
df.min()
# Out:
# cars      BMW
# counts      1
# dtype: object

# %%
df.max()
# Out:
# cars      Volvo
# counts        9
# dtype: object

# %%
df.median(numeric_only=True)
# Out:
# counts    3.0
# dtype: float64

# %%
df.count() # Returns non null values only
# Out:
# cars      7
# counts    7
# dtype: int64

# %%
df.std(numeric_only=True)
# Out:
# counts    3.199702
# dtype: float64

# %% [markdown]
# ---------- CLEANING MISSING DATA ------------

# %%
# creating a dataset with missing data

data_with_missing = {
    "cars": ["BMW", "Volvo", None, "Tesla", "Ferrari", None, "BMW"],
    "counts": [3, 7, None, 8, 1, 9, None]
}

df_missing = pd.DataFrame(data_with_missing)
print(df_missing)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     None     NaN
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5     None     9.0
# 6      BMW     NaN

# %%
# counting missing data

df_missing.isnull().sum()
# Out:
# cars      2
# counts    2
# dtype: int64

# %%
# dropna() - deleting missing data

df_missing.dropna()
df_missing.dropna(how="all")  # checks by rows with all null data
df_missing.dropna(axis=1)     # checks by column
df_missing.dropna(subset=["counts"]) # checks by subsets
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5     None     9.0

# %%
# fillna() - filling missing data

df_missing.fillna("unknown")
df_missing.fillna(0)

df_missing.fillna({"cars": "unknown", "counts": 0})
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2  unknown     0.0
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5  unknown     9.0
# 6      BMW     0.0

# %% [markdown]
# ---------- READING DATASETS ----------
#
# * scv file -> df = pd.read_csv("file_name.csv")
# * exel file -> df = pd.read_excel("file_name.xlsx")
# * json file -> df = pd.read_json("file_name.json")

# %%
df = pd.read_csv("Titanic-Dataset.csv")

df.head(30)

# df = pd.read_excel("file_name.xlsx")
# df = pd.read_json("file_name.json")
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# ---------- SAVING DATASETS ----------
#
# * to exel file -> df.to_excel("file_name.xlsx")

# %%
df.to_excel("output.xlsx")

# %%
# Series => 1D arrays

cars = pd.Series(["BMW", "Volvo", "Ford", "Tesla", "Ferrari", "Ford", "BMW"])
print(cars)
# Out:
# 0        BMW
# 1      Volvo
# 2       Ford
# 3      Tesla
# 4    Ferrari
# 5       Ford
# 6        BMW
# dtype: object

# %%
cars_series = data_with_missing['cars']
print(cars_series)
# Out:
# ['BMW', 'Volvo', None, 'Tesla', 'Ferrari', None, 'BMW']
